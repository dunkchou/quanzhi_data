# %%
#import scrapy
import urllib
import urllib2

feed_list = []
with open('./local.txt', 'r') as f:
    for line in f.readlines():
        feed_list.append(line[1:-3])

feed_list

import feedparser
user_agent = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; rv:53.0) Gecko/20100101 Firefox/53.0"

'''
for feed_url in feed_list:
    fp = feedparser.parse(feed_url, agent = user_agent)
    
    for entry in fp.entries:
        print extract_info(entry)
        print '-------------'
'''
# Out:
# "\nfor feed_url in feed_list:\n    fp = feedparser.parse(feed_url, agent = user_agent)\n    \n    for entry in fp.entries:\n        print extract_info(entry)\n        print '-------------'\n"

# %%
#### Clean up html
import requests
from readability import Document

response = requests.get('http://news.sina.com.cn/c/nd/2017-05-30/doc-ifyfqvmh9586574.shtml')
doc = Document(response.text)

print doc.title()
# Out:
# æ¹å2åå¹²é¨é­æ­å´å¼éçº§:æ­£å¤çº§è¢"éä¸ºç§å|å®åè½é©¬|åè |å ¬æ¬¾_æ°æµªæ°é"

# %%
import html2text
print html2text.html2text(doc.summary())
# Out:
# ããåæ é¢ï¼æ­å´å¼éçº§ æ¹æ½­2åæ­£å¤çº§å¹²é¨è¢«å¼é¤å
# ç±å¹¶éä¸ºç§å
#
# ããçº¢ç½æ¹æ½­ç«5æ30æ¥è®¯
# æ¥åï¼æ¹åçæ¹æ½­å¸çºªå§å¯¹å¸å§å·¡å¯ç»ç§»éçæ¹æ½­æè²å­¦é¢å¨å
# çåå
# «å¤§åè¿è§åæ¾æ´¥è¡¥è´´ãé¨åé¢é¢å¯¼å¥åææè´¹ç­é®é¢çº¿ç´¢è¿è¡äºè°æ¥ãæç
# §æ¹æ½­å¸å§è¦æ±ï¼ç»æ¹æ½­å¸çºªå§å¸¸å§ä¼è®®å®¡è®®å³å®ï¼å¯¹æ¹æ½­æè²å­¦é¢6åç­å­æåç«æ¡å®¡æ¥å¹¶ç»äºå
# çºªæ¿çºªå¤åã27æ¥ï¼æ¹æ½­å¸çºªå§å¯¹è¯¥æ¡ä»¶æå³æ
# åµè¿è¡äºéæ¥ã
#
# ããç»æ¥ï¼2013å¹´1æè³2016å¹´5ææé´ï¼æ¹æ½­æè²å­¦é¢æ¶ä»»å
# å§ä¹¦è®°æéåºè¿åæ¿æ²»çºªå¾ï¼å¯¹æç»ç»å®¡æ¥ï¼è¿åå»æ´çºªå¾ï¼åä¸å³ç­è¿è§åæ¾æ´¥è¡¥è´´ï¼è¿åå½å®¶æ³å¾æ³è§è§å®ï¼éåèå¼è´­ä¹¦åç¥¨çæ¹å¼å¥åæææ¬¾å½ä¸ªäººä½¿ç¨ï¼éåèåæ¯åºãèå¼åç¥¨ãå£å¤´åæ´ä¹¦é¢ååçº¦å®ç­æ¹å¼å°å
# ¬æ¬¾å ä¸ºå·±æãç»å¸çºªå§å¸¸å§ä¼è®®ç
# ç©¶å¹¶æ¥å¸å§æ¹åï¼å³å®ç»äºæéåºå¼é¤å
# ç±å¤åï¼ç»å¸çå¯å±å±é¿åå¬ä¼è®®ç
# ç©¶å¹¶æ¥å¸æ¿åºæ¹åï¼å³å®ç»äºæéåºæ¤èå¤åï¼éä¸ºç§åã
# ¬æ¬¾ç¨äºåæ¾æçè´¹ç¨ãç»å¸çºªå§å¸¸å§ä¼è®®ç
# ç©¶ï¼å³å®ç»äºçå»ºå¹³ä¸¥éè­¦åå¤åã
#
# ããæ¶ä»»åå§å§åãçºªå§ä¹¦è®°é³åæå±¥è¡å¨é¢ä»ä¸¥æ²»å
# çç£è´£ä»»ä¸åï¼å¯¹æ¹æ½­æè²å­¦é¢åçéå¤§è¿çºªï¼é¢é¢å¯¼ç­å­åä¸­å±å¹²é¨èå·¥å¤äººè¢«ç«æ¡æ¥å¤åç»ç»å¤çé®é¢ï¼è´æçç£è´£ä»»ãç»å¸çºªå§å¸¸å§ä¼è®®ç
# ç©¶ï¼å³å®ç»äºé³åæè­¦åå¤åã
#
# ããéæ¥æåºï¼æ¹æ½­æè²å­¦é¢å
# å§ç­å­æåæ¬åºå¸¦å¤´è½å®ä¸­å¤®å«é¡¹è§å®ç²¾ç¥ï¼ä½ä»ä»¬æ è§å
# ççºªå¾ãè§ç©åä¸­å¤®åå³åå¯¹âåé£âçè¦æ±ï¼å¨åçåå
# «å¤§åä¸æ¶æãä¸æ¶æï¼æä»¤ä¸è¡ãæç¦ä¸æ­¢ï¼é¡¶é£è¿çºªï¼æ§è´¨æ¶å£ï¼å½±åå¾åï¼ä¸¥éæå®³äºå
# ç»ç»çå½¢è±¡åå
# ¬ä¿¡åãæ­¤æ¬¡æ¹æ½­æè²å­¦é¢6åç­å­æåè¢«æ¥å¤ï¼2åä¸»è¦é¢å¯¼è¢«æ­å´å¼å¤çï¼æè®­æä¸ºæ¨çãåäººæ·±çï¼å
# ¨å¸å¹¿å¤§å
# åå¹²é¨ç¹å«æ¯é¢å¯¼å¹²é¨è¦ä»ä¸­æ±²åæ·±å»æè®­ï¼å¼ä»¥ä¸ºæã
#
# ããéæ¥è¦æ±ï¼å¨é¢ä»ä¸¥æ²»åï¼è´¯å½»è½å®ä¸­å¤®å
# «é¡¹è§å®ç²¾ç¥ãå å¼ºä½é£å»ºè®¾æ°¸è¿å¨è·¯ä¸ãå¨å¸å¹¿å¤§å
# åå¹²é¨ç¹å«æ¯é¢å¯¼å¹²é¨è¦å§ç»ä¿ææ¸
# éå¤´èï¼åæ¿æ²»ä¸çæç½äººï¼ä¸¥æ
# ¼å»æ´èªå¾ï¼åå³é²æ­¢âåé£âé®é¢åå¼¹åæ½®ã
#
# ããæ¥æºï¼çº¢ç½
#
# è´£ä»»ç¼è¾ï¼ååå

# %%
def extract_info(fp_entry):
    #### Extract information from each RSS Feed
    author = fp_entry.get('author', '')
    id = fp_entry.get('link', '')
    link = fp_entry.get('link', '')
    published = fp_entry.get('published', '')
    summary = fp_entry.get('summary', '')
    title = fp_entry.get('title', '')
    
    
    tags_list = []
    for tt in fp_entry.get('tags', [{}]):
        tags_list.append(tt.get('term', ''))

    
    if id == '':
        print 'Null URL'
        return []
    else:
        return [id, author, link, published, summary, title, '*'.join(tags_list)]
